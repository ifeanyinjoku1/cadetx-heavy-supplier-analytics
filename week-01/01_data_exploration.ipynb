# %% [markdown]
# # Week 1: Exploratory Data Analysis (EDA)
# **Project:** Heavy Supplier, Inventory & Warehouse Analytics
# **Author:** Ifeanyi Njoku (Scrum Master)
# **Team:** CX-2026-HSWA-19

# %%
import pandas as pd
import numpy as np

# Load core relational datasets
branches_df = pd.read_csv('branches.csv')
inventory_df = pd.read_csv('inventory_master.csv')
suppliers_df = pd.read_csv('suppliers.csv')
products_df = pd.read_csv('products.csv')
sales_df = pd.read_csv('sales_orders_header.csv')

# %% [markdown]
# ## 1. Dataset Dimensions & Overview
# Checking overall structure, row counts, and primary attributes across tables.

# %%
tables = {
    'Branches': branches_df,
    'Inventory Master': inventory_df,
    'Suppliers': suppliers_df,
    'Products': products_df,
    'Sales Orders': sales_df
}

for name, df in tables.items():
    print(f"=== {name} Table ===")
    print(f"Shape: {df.shape}")
    print(df.info())
    print("\n")

# %% [markdown]
# ## 2. Summary Statistics
# Analyzing baseline metrics for inventory stock levels and supplier pricing profiles.

# %%
# Numerical distribution of inventory stock levels
inventory_df.describe()

# %% [markdown]
# ## 3. High-Level Categorical Distributions
# Evaluating warehouse branch distribution and top product category counts.

# %%
# Inventory count grouped by regional branch
inventory_df['branch_id'].value_counts()

# Product distribution by category
products_df['category'].value_counts()
