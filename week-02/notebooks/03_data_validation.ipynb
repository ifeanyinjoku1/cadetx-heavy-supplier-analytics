# %%
# Data Validation Script
import pandas as pd

# Load datasets
sales_lines = pd.read_csv('../../data/sales_orders_lines.csv')
sales_header = pd.read_csv('../../data/sales_orders_header.csv')

print('Sales Lines count:', len(sales_lines))
print('Sales Header count:', len(sales_header))
